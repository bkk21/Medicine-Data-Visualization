# %%
import requests
import xml.etree.ElementTree as ET

# API 인증키
service_key = "7w8yGDAgOEqoA83iJfNVoW1VVPfWSQNWBXhsogrBzgifRXJYTwWE8CMKnlP9KT5gNV5VGC3X3vGIFWyphY5o1A=="

# 검색어가 저장된 txt 파일 열기
filename = "C:\\Users\\qhrud\\Desktop\\medicine.txt"
with open(filename, "r", encoding="utf-8") as f:
    for line in f:
        item_name = line.strip() + "텔미콜정"
        # 검색어로 활용할 코드 작성

# 검색어별로 결과 출력
for search in search_list:
    # 검색어에서 개행문자 제거
    item_name = search.strip()

    # API 요청 URL 생성
    url = "https://apis.data.go.kr/1471000/MdcinGrnIdntfcInfoService01/getMdcinGrnIdntfcInfoList01"
    url += f"?serviceKey={service_key}&item_name={item_name}"

    # API 요청
    response = requests.get(url)

    # 응답 XML 파싱
    root = ET.fromstring(response.content)

    # 검색 결과 출력
    if root.findtext("header/resultCode") == "00":
        items = root.findall("body/items/item")
        for item in items:
            print(f"{item.findtext('ITEM_NAME')} ({item.findtext('ENTP_NAME')})")
    else:
        print(f"검색 결과가 없습니다: {item_name}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 15
#      11         item_name = line.strip() + "텔미콜정"
#      12         # 검색어로 활용할 코드 작성
#      13
#      14 # 검색어별로 결과 출력
# ---> 15 for search in search_list:
#      16     # 검색어에서 개행문자 제거
#      17     item_name = search.strip()
#      19     # API 요청 URL 생성
#
# NameError: name 'search_list' is not defined

# %%
import requests
from bs4 import BeautifulSoup

service_key = '7w8yGDAgOEqoA83iJfNVoW1VVPfWSQNWBXhsogrBzgifRXJYTwWE8CMKnlP9KT5gNV5VGC3X3vGIFWyphY5o1A%3D%3D'
base_url = 'https://apis.data.go.kr/1471000/MdcinGrnIdntfcInfoService01/getMdcinGrnIdntfcInfoList01'

with open('C:\\Users\\qhrud\\Desktop\\medicine.txt', 'r', encoding='utf-8') as f:
    item_name_list = f.read().splitlines()

for item_name in item_name_list:
    url = base_url + '?serviceKey=' + service_key + '&item_name=' + item_name
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    items = soup.find_all('item')

    if len(items) == 0:
        print(f'{item_name}에 대한 검색 결과가 없습니다.')
    else:
        for item in items:
            item_seq = item.find('item_seq').text
            item_name = item.find('item_name').text
            entp_name = item.find('entp_name').text
            print(f'품목일련번호: {item_seq}, 품목명: {item_name}, 업체명: {entp_name}')
# Out:
# 품목일련번호: 201206529, 품목명: 글로미피드정(레바미피드), 업체명: (주)한국글로벌제약
# 품목일련번호: 201206613, 품목명: 레바피드정(레바미피드), 업체명: 동국제약(주)
# 품목일련번호: 201207596, 품목명: 미피드정(레바미피드), 업체명: (주)팜젠사이언스
# 품목일련번호: 201207452, 품목명: 휴레바정(레바미피드), 업체명: 한국휴텍스제약(주)
# 품목일련번호: 201304290, 품목명: 레바진정(레바미피드), 업체명: 이연제약(주)
# 품목일련번호: 201305785, 품목명: 레바피론정(레바미피드), 업체명: (주)한국파비스제약
# 품목일련번호: 201300148, 품목명: 레바틸정(레바미피드), 업체명: (주)바이넥스
# 품목일련번호: 201300892, 품목명: 레비스정(레바미피드), 업체명: 대우제약(주)
# 품목일련번호: 201301227, 품목명: 레바마정(레바미피드), 업체명: 미래바이오제약(주)
# 품목일련번호: 201302169, 품목명: 레스탐정(레바미피드), 업체명: 하나제약(주)
# 품목일련번호: 201205832, 품목명: 록스핀정(록소프로펜나트륨수화물), 업체명: 한국유나이티드제약(주)
# 품목일련번호: 201206201, 품목명: 로펜탁정60밀리그램(록소프로펜나트륨수화물), 업체명: 환인제약(주)
# 품목일련번호: 201205038, 품목명: 리록스정(록소프로펜나트륨수화물), 업체명: (주)한국파마
# 품목일련번호: 201206759, 품목명: 록소리스정(록소프로펜나트륨수화물), 업체명: (주)동구바이오제약
# 품목일련번호: 201206760, 품목명: 록프로펜정(록소프로펜나트륨수화물), 업체명: 제이더블유신약(주)
# 품목일련번호: 201305793, 품목명: 경보록소프로펜나트륨수화물정, 업체명: (주)경보제약
# 품목일련번호: 201306117, 품목명: 록소브이정60밀리그램(록소프로펜나트륨수화물), 업체명: (주)엘지화학
# ...

# %%
import requests
from bs4 import BeautifulSoup

service_key = '7w8yGDAgOEqoA83iJfNVoW1VVPfWSQNWBXhsogrBzgifRXJYTwWE8CMKnlP9KT5gNV5VGC3X3vGIFWyphY5o1A%3D%3D'
base_url = 'https://apis.data.go.kr/1471000/MdcinGrnIdntfcInfoService01/getMdcinGrnIdntfcInfoList01'

filename = "C:/Users/qhrud/Desktop/medicine.txt"
with open(filename, "r", encoding="utf-8") as f:
    item_name_list = f.read().splitlines()

for item_name in item_name_list:
    url = base_url + '?serviceKey=' + service_key + '&item_name=' + item_name
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    items = soup.find_all('item')
    
    print(f'검색할 성분 - {item_name}')

    if len(items) == 0:
        print(f'{item_name}에 대한 검색 결과가 없습니다.')
    else:
        for item in items:
            item_seq = item.find('item_seq').text
            item_name = item.find('item_name').text
            class_name = item.find('class_name').text
            print(f'품목일련번호: {item_seq}, 품목명: {item_name}, CLASS_NAME: {class_name}')
    print("-----------------------------------------------------------------------------------------------\n")
# Out:
# 검색할 성분 - 레바미피드
# 품목일련번호: 201206529, 품목명: 글로미피드정(레바미피드), CLASS_NAME: 소화성궤양용제
# 품목일련번호: 201206613, 품목명: 레바피드정(레바미피드), CLASS_NAME: 소화성궤양용제
# 품목일련번호: 201207596, 품목명: 미피드정(레바미피드), CLASS_NAME: 소화성궤양용제
# 품목일련번호: 201207452, 품목명: 휴레바정(레바미피드), CLASS_NAME: 소화성궤양용제
# 품목일련번호: 201304290, 품목명: 레바진정(레바미피드), CLASS_NAME: 소화성궤양용제
# 품목일련번호: 201305785, 품목명: 레바피론정(레바미피드), CLASS_NAME: 소화성궤양용제
# 품목일련번호: 201300148, 품목명: 레바틸정(레바미피드), CLASS_NAME: 소화성궤양용제
# 품목일련번호: 201300892, 품목명: 레비스정(레바미피드), CLASS_NAME: 소화성궤양용제
# 품목일련번호: 201301227, 품목명: 레바마정(레바미피드), CLASS_NAME: 소화성궤양용제
# 품목일련번호: 201302169, 품목명: 레스탐정(레바미피드), CLASS_NAME: 소화성궤양용제
# -----------------------------------------------------------------------------------------------
#
# 검색할 성분 - 록소프로펜나트륨수화물
# 품목일련번호: 201205832, 품목명: 록스핀정(록소프로펜나트륨수화물), CLASS_NAME: 해열.진통.소염제
# 품목일련번호: 201206201, 품목명: 로펜탁정60밀리그램(록소프로펜나트륨수화물), CLASS_NAME: 해열.진통.소염제
# 품목일련번호: 201205038, 품목명: 리록스정(록소프로펜나트륨수화물), CLASS_NAME: 해열.진통.소염제
# ...

# %%
import requests
from bs4 import BeautifulSoup

service_key = '7w8yGDAgOEqoA83iJfNVoW1VVPfWSQNWBXhsogrBzgifRXJYTwWE8CMKnlP9KT5gNV5VGC3X3vGIFWyphY5o1A%3D%3D'
base_url = 'https://apis.data.go.kr/1471000/MdcinGrnIdntfcInfoService01/getMdcinGrnIdntfcInfoList01'

with open('C:/Users/qhrud/Desktop/medicine.txt', 'r', encoding='utf-8') as f:
    item_name_list = [line.strip() for line in f.readlines()]

with open('C:/Users/qhrud/Desktop/result.txt', 'w', encoding='utf-8') as f:
    for item_name in item_name_list:
        url = base_url + '?serviceKey=' + service_key + '&item_name=' + item_name
        response = requests.get(url)
        soup = BeautifulSoup(response.content, 'html.parser')
        items = soup.find_all('item')

        if len(items) == 0:
            f.write(f'{item_name}에 대한 검색 결과가 없습니다.\n')
        else:
            for item in items:
                item_seq = item.find('item_seq').text
                item_name = item.find('item_name').text
                class_name = item.find('class_name').text
                entp_name = item.find('entp_name').text
                f.write(f'품목일련번호 {item_seq} 품목명 {item_name} 분류명 {class_name} 업체명 {entp_name}\n')

# %%
with open('medicine_name.txt', 'r', encoding='utf-8') as f:
    word_found = False
    for word in f:
        word = word.strip()
        with open('medicine_match.txt', 'r', encoding='utf-8') as g:
            for line in g:
                if word in line:
                    print(line.strip())
                    word_found = True
            if not word_found:
                print(f"'{word}' is not in the file")
            word_found = False
# Out:
# 222901ATB 레바미피드
# 421001ATB 모사프리드시트르산염이수화물
# 186101ATB 록소프로펜나트륨
# 430101ATB 애엽95%에탄올연조엑스(20→1
# 100901ATB 아세클로페낙

# %%
with open('code_list.txt', 'r', encoding='utf-8') as f:
    for word in f:
        word = word.strip()
        print(f"검색할 약 코드: {word}\n")
        with open('medicine_list.txt', 'r', encoding='utf-8') as g:
            word_found = False
            for line in g:
                if word in line:
                    print(line.strip())
                    word_found = True
                    break  # 첫 번째 결과만 출력하도록 break 추가
            if not word_found:
                print(f"'{word}'은(는) 파일에 존재하지 않습니다.")
        print("---------------------------------------------------------\n")
# Out:
# 검색할 약 코드: 222901ATB
#
# 레비스틴정(레바미피드)	222901ATB
# ---------------------------------------------------------
#
# 검색할 약 코드: 421001ATB
#
# 가스모프정(모사프리드시트르산염이수화물)	421001ATB
# ---------------------------------------------------------
#
# 검색할 약 코드: 113232APD
#
# 비스칸엔산(바실루스리케니포르미스균)	113232APD
# ---------------------------------------------------------
#
# 검색할 약 코드: 244305ATB
#
# 위메부틴정150밀리그램(트리메부틴말레산염)	244305ATB
# ---------------------------------------------------------
#
# 검색할 약 코드: 105203ATB
#
# 아마가정(알마게이트)	105203ATB
# ---------------------------------------------------------
#
# 검색할 약 코드: 187402ATB
#
# 마그사이드정500밀리그람(수산화마그네슘)	187402ATB
# ---------------------------------------------------------
#
# 검색할 약 코드: 186101ATB
#
# 록소핀정(록소프로펜나트륨)	186101ATB
# ---------------------------------------------------------
#
# 검색할 약 코드: 152301ATB
#
# 에페나정(에페리손염산염)	152301ATB
# ---------------------------------------------------------
#
# 검색할 약 코드: 480600ATB
#
# 다노펜세미정	480600ATB
# ...

# %%
import re

with open('code_list.txt', 'r', encoding='utf-8') as f:
    for word in f:
        word = word.strip()
        print(f"{word} ", end="")
        with open('medicine_list.txt', 'r', encoding='utf-8') as g:
            word_found = False
            for line in g:
                if word in line:
                    matched = re.search(r'\((.*?)\)', line)
                    if matched:
                        print(matched.group(1))
                        word_found = True
                        break
            if not word_found:
                print(f"'{word}'은(는) 파일에 존재하지 않습니다.")

# %%
import re

with open('code_list.txt', 'r', encoding='utf-8') as f:
    for word in f:
        word = word.strip()
        print(f"{word} ", end="")
        with open('medicine_list.txt', 'r', encoding='utf-8') as g:
            word_found = False
            for line in g:
                if word in line:
                    matched = re.search(r'\((.*?)\)', line)
                    if matched:
                        print(matched.group(1))
                        word_found = True
                        break
            if not word_found:
                print(f"'{word}'은(는) 파일에 존재하지 않습니다.")

# %%
import re

not_found = []

with open('code_list.txt', 'r', encoding='utf-8') as f:
    for word in f:
        word = word.strip()
        with open('medicine_list.txt', 'r', encoding='utf-8') as g:
            word_found = False
            for line in g:
                if word in line:
                    matched = re.search(r'\((.*?)\)', line)
                    if matched:
                        print(f"{word} {matched.group(1)}")
                        word_found = True
                        break
            if not word_found:
                not_found.append(word)

print("\n검색 실패한 약 코드:")
for word in not_found:
    print(word)
# Out:
# 222901ATB 레바미피드
# 421001ATB 모사프리드시트르산염이수화물
# 113232APD 바실루스리케니포르미스균
# 244305ATB 트리메부틴말레산염
# 105203ATB 알마게이트
# 187402ATB 수산화마그네슘
# 186101ATB 록소프로펜나트륨
# 152301ATB 에페리손염산염
# 480600ATB 수출용
# 430101ATB 애엽95%에탄올연조엑스(20→1
# 142303ATB 덱시부프로펜디.씨
# 105502ATB 알프라졸람
# 183501ATB 레보설피리드
# 240301ATB 티로프라미드염산염
# 101804ACH 아세틸시스테인
# 101430ATR 아세트아미노펜
# 244301ATB 트리메부틴말레산염
# 249901ATB 잘토프로펜
# 217001ATB 프레드니솔론
# 234401ATB 탈니플루메이트
# 142301ATB 덱시부프로펜
# 192004ATB 수출명:디베파닐정(Dibefaniltablet
# 513000ATB 수출용
# 193302ATB 메틸프레드니솔론
# 131801ATB 클로르페니라민말레산염
# 179001ATB 이토프리드염산염
# 438901ATB 스트렙토키나제·스트렙토도르나제
# 153101ACH 에르도스테인
# 101404ATB 아세트아미노펜제피세립
# 133301ATB 시메티딘
# 490303ATB 펠라고니움시도이데스11%에탄올건조엑스(5.5~6.6→1
# 102502ATB 아클라토늄나파디실산염
# 203801ATB 옥틸로늄브롬화물
# 189001ACH 메페남산
# 142903ATB 디아제팜
# 294300ACS 수출명:알베치콘연질캡슐
# 185102ACH 로페라미드염산염
# 228202ACH 소브레롤
# 113501ATB 바클로펜
# 142801ACH 디아세레인
# 219901ATB 프로프라놀롤염산염
# 157301ATB 파모티딘
# 146431ASS 디옥타헤드랄스멕타이트
# 244302ATB 트리메부틴말레산염
# 194101ATB 메트로니다졸
# 244303ATR 트리메부틴말레산염
# ...

# %%
#1번 - 주성분 코드와 이름 연결
#code
import re

not_found = []

with open('code_list.txt', 'r', encoding='utf-8') as f:
    with open('medicine_match.txt', 'w', encoding='utf-8') as h:
        for word in f:
            word = word.strip()
            with open('medicine_list.txt', 'r', encoding='utf-8') as g:
                word_found = False
                for line in g:
                    if word in line:
                        matched = re.search(r'\((.*?)\)', line)
                        if matched:
                            result = f"{word} {matched.group(1)}"
                            #print(result)
                            h.write(result + '\n')
                            word_found = True
                            break
                if not word_found:
                    not_found.append(word)
        
        if not_found:
            h.write("\n검색 실패한 약 코드\n")
            for word in not_found:
                #print(f"'{word}'은(는) 파일에 존재하지 않습니다.")
                h.write(word + '\n')

# %%
# 2번 - 코드로 주성분 이름 검색 
with open('medicine_name.txt', 'r', encoding='utf-8') as f, open('medicine.txt', 'w', encoding='utf-8') as out_f:
    for word in f:
        word = word.strip()
        with open('medicine_match.txt', 'r', encoding='utf-8') as g:
            word_found = False
            for line in g:
                if word in line:
                    out_f.write(" ".join(line.strip().split()[1:]) + "\n")
                    word_found = True
                    break
            if not word_found:
                out_f.write(f"'{word}'은(는) 파일에 존재하지 않습니다.\n")

# %%
#오픈 API에서 검색

import requests
from bs4 import BeautifulSoup

service_key = '7w8yGDAgOEqoA83iJfNVoW1VVPfWSQNWBXhsogrBzgifRXJYTwWE8CMKnlP9KT5gNV5VGC3X3vGIFWyphY5o1A%3D%3D'
base_url = 'https://apis.data.go.kr/1471000/MdcinGrnIdntfcInfoService01/getMdcinGrnIdntfcInfoList01'

filename = "C:/Users/qhrud/Desktop/medicine.txt"
with open(filename, "r", encoding="utf-8") as f:
    item_name_list = f.read().splitlines()

for item_name in item_name_list:
    url = base_url + '?serviceKey=' + service_key + '&item_name=' + item_name
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    items = soup.find_all('item')
    
    print(f'검색할 성분 - {item_name}')

    if len(items) == 0:
        print(f'{item_name}에 대한 검색 결과가 없습니다.')
    else:
        for item in items:
            item_seq = item.find('item_seq').text
            item_name = item.find('item_name').text
            class_name = item.find('class_name').text
            print(f'품목일련번호: {item_seq}, 품목명: {item_name}, CLASS_NAME: {class_name}')
    print("-----------------------------------------------------------------------------------------------\n")
# Out:
# 검색할 성분 - 레바미피드
# 품목일련번호: 201206529, 품목명: 글로미피드정(레바미피드), CLASS_NAME: 소화성궤양용제
# 품목일련번호: 201206613, 품목명: 레바피드정(레바미피드), CLASS_NAME: 소화성궤양용제
# 품목일련번호: 201207596, 품목명: 미피드정(레바미피드), CLASS_NAME: 소화성궤양용제
# 품목일련번호: 201207452, 품목명: 휴레바정(레바미피드), CLASS_NAME: 소화성궤양용제
# 품목일련번호: 201304290, 품목명: 레바진정(레바미피드), CLASS_NAME: 소화성궤양용제
# 품목일련번호: 201305785, 품목명: 레바피론정(레바미피드), CLASS_NAME: 소화성궤양용제
# 품목일련번호: 201300148, 품목명: 레바틸정(레바미피드), CLASS_NAME: 소화성궤양용제
# 품목일련번호: 201300892, 품목명: 레비스정(레바미피드), CLASS_NAME: 소화성궤양용제
# 품목일련번호: 201301227, 품목명: 레바마정(레바미피드), CLASS_NAME: 소화성궤양용제
# 품목일련번호: 201302169, 품목명: 레스탐정(레바미피드), CLASS_NAME: 소화성궤양용제
# -----------------------------------------------------------------------------------------------
#
# 검색할 성분 - 모사프리드시트르산염이수화물
# 품목일련번호: 200809076, 품목명: 가스프렌정(모사프리드시트르산염이수화물), CLASS_NAME: 기타의 소화기관용약
# 품목일련번호: 201208723, 품목명: 가스잘정(모사프리드시트르산염이수화물), CLASS_NAME: 기타의 소화기관용약
# 품목일련번호: 201209717, 품목명: 가스티인정(모사프리드시트르산염이수화물), CLASS_NAME: 기타의 소화기관용약
# ...

# %%
import requests
from bs4 import BeautifulSoup

service_key = '7w8yGDAgOEqoA83iJfNVoW1VVPfWSQNWBXhsogrBzgifRXJYTwWE8CMKnlP9KT5gNV5VGC3X3vGIFWyphY5o1A%3D%3D'
base_url = 'https://apis.data.go.kr/1471000/MdcinGrnIdntfcInfoService01/getMdcinGrnIdntfcInfoList01'

filename = "C:/Users/qhrud/Desktop/medicine.txt"
with open(filename, "r", encoding="utf-8") as f:
    item_name_list = f.read().splitlines()

for item_name in item_name_list:
    url = base_url + '?serviceKey=' + service_key + '&item_name=' + item_name
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    items = soup.find_all('item')

    print(f'검색할 성분 - {item_name}')

    if len(items) == 0:
        print(f'{item_name}에 대한 검색 결과가 없습니다.')
    else:
        item = items[0]  # 첫 번째 결과만 사용
        item_seq = item.find('item_seq').text
        item_name = item.find('item_name').text
        class_name = item.find('class_name').text
        print(f'품목일련번호: {item_seq}, 품목명: {item_name}, CLASS_NAME: {class_name}')

    print("-----------------------------------------------------------------------------------------------\n")
# Out:
# 검색할 성분 - 레바미피드
# 품목일련번호: 201206529, 품목명: 글로미피드정(레바미피드), CLASS_NAME: 소화성궤양용제
# -----------------------------------------------------------------------------------------------
#
# 검색할 성분 - 모사프리드시트르산염이수화물
# 품목일련번호: 200809076, 품목명: 가스프렌정(모사프리드시트르산염이수화물), CLASS_NAME: 기타의 소화기관용약
# -----------------------------------------------------------------------------------------------
#
# 검색할 성분 - 록소프로펜나트륨
# 품목일련번호: 201101493, 품목명: 록스펜씨알정(록소프로펜나트륨), CLASS_NAME: 해열.진통.소염제
# -----------------------------------------------------------------------------------------------
#
# 검색할 성분 - 애엽95%에탄올
# 애엽95%에탄올에 대한 검색 결과가 없습니다.
# -----------------------------------------------------------------------------------------------
#
# 검색할 성분 - 아세클로페낙
# 품목일련번호: 201002745, 품목명: 클란자CR정(아세클로페낙), CLASS_NAME: 해열.진통.소염제
# -----------------------------------------------------------------------------------------------

# %%
# 2번 - 코드로 주성분 이름 검색 
with open('medicine_name.txt', 'r', encoding='utf-8') as f, open('medicine.txt', 'w', encoding='utf-8') as out_f:
    for word in f:
        word = word.strip()
        with open('medicine_match.txt', 'r', encoding='utf-8') as g:
            word_found = False
            for line in g:
                if word in line:
                    out_f.write(" ".join(line.strip().split()[1:]) + "\n")
                    word_found = True
                    break
            if not word_found:
                out_f.write(f"'{word}'은(는) 파일에 존재하지 않습니다.\n")

# %%
import requests
from bs4 import BeautifulSoup

service_key = '7w8yGDAgOEqoA83iJfNVoW1VVPfWSQNWBXhsogrBzgifRXJYTwWE8CMKnlP9KT5gNV5VGC3X3vGIFWyphY5o1A%3D%3D'
base_url = 'https://apis.data.go.kr/1471000/MdcinGrnIdntfcInfoService01/getMdcinGrnIdntfcInfoList01'

filename = "C:/Users/qhrud/Desktop/medicine.txt"
with open(filename, "r", encoding="utf-8") as f:
    item_name_list = f.read().splitlines()

for item_name in item_name_list:
    url = base_url + '?serviceKey=' + service_key + '&item_name=' + item_name
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    items = soup.find_all('item')

    print(f'{item_name} - ', end="")

    if len(items) == 0:
        print(f'{item_name}에 대한 검색 결과가 없습니다.')
    else:
        item = items[0]  # 첫 번째 결과만 사용
        item_seq = item.find('item_seq').text
        item_name = item.find('item_name').text
        class_name = item.find('class_name').text
        print(f'{class_name}')
# Out:
# 레바미피드 - 소화성궤양용제
# 록소프로펜나트륨 - 해열.진통.소염제
# 아세트아미노펜 - 해열.진통.소염제
# 모사프리드시트르산염이수화물 - 기타의 소화기관용약
# 세파클러수화물 - 주로 그람양성, 음성균에 작용하는 것
# 레바미피드 - 소화성궤양용제

# %%
#같은 성분끼리 묶기 
with open('code_list.txt', 'r', encoding='utf-8') as f, open('medicine_match_2.txt', 'w', encoding='utf-8') as out_f:
    for word in f:
        word = word.strip()
        with open('medicine_match.txt', 'r', encoding='utf-8') as g:
            word_found = False
            for line in g:
                if word in line:
                    out_f.write(" ".join(line.strip().split()[1:]) + "\n")
                    word_found = True
                    break
            if not word_found:
                out_f.write(f"'{word}'은(는) 파일에 존재하지 않습니다.\n")

# %%
#효능별 주성분 
import requests
from bs4 import BeautifulSoup

service_key = '7w8yGDAgOEqoA83iJfNVoW1VVPfWSQNWBXhsogrBzgifRXJYTwWE8CMKnlP9KT5gNV5VGC3X3vGIFWyphY5o1A%3D%3D'
base_url = 'https://apis.data.go.kr/1471000/MdcinGrnIdntfcInfoService01/getMdcinGrnIdntfcInfoList01'

filename = "C:/Users/qhrud/Desktop/medicine_match_2.txt"
with open(filename, "r", encoding="utf-8") as f:
    item_name_list = f.read().splitlines()

for item_name in item_name_list:
    url = base_url + '?serviceKey=' + service_key + '&item_name=' + item_name
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    items = soup.find_all('item')
    
    print(f'성분명 - {class_name}\n')

    if len(items) == 0:
        print(f'{item_name}에 대한 검색 결과가 없습니다.')
    else:
        for item in items:
            item_seq = item.find('item_seq').text
            item_name = item.find('item_name').text.replace('(', '').replace(')', '') # 수정된 부분
            class_name = item.find('class_name').text
            print(f'{item_name}')
    print("-----------------------------------------------------------------------------------------------\n")
# Out:
# 성분명 - 소화성궤양용제
#
# 글로미피드정레바미피드
# 레바피드정레바미피드
# 미피드정레바미피드
# 휴레바정레바미피드
# 레바진정레바미피드
# 레바피론정레바미피드
# 레바틸정레바미피드
# 레비스정레바미피드
# 레바마정레바미피드
# 레스탐정레바미피드
# -----------------------------------------------------------------------------------------------

# %%
import requests
from bs4 import BeautifulSoup

service_key = '7w8yGDAgOEqoA83iJfNVoW1VVPfWSQNWBXhsogrBzgifRXJYTwWE8CMKnlP9KT5gNV5VGC3X3vGIFWyphY5o1A%3D%3D'
base_url = 'https://apis.data.go.kr/1471000/MdcinGrnIdntfcInfoService01/getMdcinGrnIdntfcInfoList01'

filename = "C:/Users/qhrud/Desktop/medicine_match_2.txt"
save_dir = "C:/Users/qhrud/Desktop/medicine_group/"

with open(filename, "r", encoding="utf-8") as f:
    item_name_list = f.read().splitlines()

for item_name in item_name_list:
    url = base_url + '?serviceKey=' + service_key + '&item_name=' + item_name
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    items = soup.find_all('item')
    
    class_name = ""
    if len(items) == 0:
        print(f'{item_name}에 대한 검색 결과가 없습니다.')
    else:
        for item in items:
            class_name = item.find('class_name').text
            item_name = item.find('item_name').text.replace('(', '').replace(')', '')
            print(f'{item_name}')
        
        # 파일 저장
        file_path = save_dir + class_name + ".txt"
        with open(file_path, "a", encoding="utf-8") as f:
            f.write("\n".join(item_name_list) + "\n")
            
    print("-----------------------------------------------------------------------------------------------\n")
# Out:
# 글로미피드정레바미피드
# 레바피드정레바미피드
# 미피드정레바미피드
# 휴레바정레바미피드
# 레바진정레바미피드
# 레바피론정레바미피드
# 레바틸정레바미피드
# 레비스정레바미피드
# 레바마정레바미피드
# 레스탐정레바미피드
# -----------------------------------------------------------------------------------------------
